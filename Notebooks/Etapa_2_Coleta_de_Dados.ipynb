# %% [markdown]
# ### Apresentação do Projeto
# Proposta para a construção de uma aplicação que realiza análise de sentimentos à presidência.

# %% [markdown]
# Intalação das Bibliotecas

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.4

# %% [markdown]
# Importando as Bibliotecas

# %%
import snscrape.modules.twitter as sntwitter
#Manipulação de Dados
import pandas as pd

# %%
maximo_de_tweets=50

# %% [markdown]
# ### Lula

# %%
lista_de_tweets_lula = []

# %%
for i, tweet in enumerate (sntwitter.TwitterSearchScraper(['lula']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_lula.append([tweet.date, tweet.id, tweet.content])

# %%
type(lista_de_tweets_lula)
# Out:
# list

# %%
dataframe_tweets_lula = pd.DataFrame(lista_de_tweets_lula, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head ()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:17:46+00:00  1553520255238119424
# 1 2022-07-30 23:17:46+00:00  1553520253535227906
# 2 2022-07-30 23:17:45+00:00  1553520252608192512
# 3 2022-07-30 23:17:45+00:00  1553520251211505664
# 4 2022-07-30 23:17:45+00:00  1553520250263687168
#
#                                                Tweet
# 0  @LulaOficial @dilmabr Alguém de vcs checa isso...
# 1  Presidente: Lula; Senador:?; Deputado Federal:...
# 2  @gleisi @LulaOficial @CamiloSantanaCE @elmanof...
# 3        @MARCOSDANI1 @LulaOficial NÃO...BEM REAL...
# 4  @WesleyAHS11s @LulaOficial #BolsonaroReeleitoE...

# %%
dataframe_tweets_lula['Candidato'] = 'Lula'

# %%
dataframe_tweets_lula.head ()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:17:46+00:00  1553520255238119424
# 1 2022-07-30 23:17:46+00:00  1553520253535227906
# 2 2022-07-30 23:17:45+00:00  1553520252608192512
# 3 2022-07-30 23:17:45+00:00  1553520251211505664
# 4 2022-07-30 23:17:45+00:00  1553520250263687168
#
#                                                Tweet Candidato
# 0  @LulaOficial @dilmabr Alguém de vcs checa isso...      Lula
# 1  Presidente: Lula; Senador:?; Deputado Federal:...      Lula
# 2  @gleisi @LulaOficial @CamiloSantanaCE @elmanof...      Lula
# 3        @MARCOSDANI1 @LulaOficial NÃO...BEM REAL...      Lula
# 4  @WesleyAHS11s @LulaOficial #BolsonaroReeleitoE...      Lula

# %% [markdown]
# ### Bolsonaro

# %%
lista_de_tweets_bolsonaro = []

# %%
for i, tweet in enumerate (sntwitter.TwitterSearchScraper(['bolsonaro']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_bolsonaro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_bolsonaro = pd.DataFrame(lista_de_tweets_bolsonaro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_bolsonaro.head ()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:17:32+00:00  1553520196110917633
# 1 2022-07-30 23:17:32+00:00  1553520195670622208
# 2 2022-07-30 23:17:31+00:00  1553520194328330242
# 3 2022-07-30 23:17:31+00:00  1553520193506271232
# 4 2022-07-30 23:17:31+00:00  1553520192369688578
#
#                                                Tweet
# 0                     @jairbolsonaro Famoso gadogram
# 1  @Pauloeuaqui1 @jairbolsonaro Quem tem medo é o...
# 2  Fugir para os EUA,com certeza não vai garantir...
# 3  @Antnio3070 @MarcioM61326104 @adinaelsilva @Al...
# 4  O Manifesto do Direito via USP, com 500 mil as...

# %%
dataframe_tweets_bolsonaro['Candidato'] = 'Bolsonaro'

# %%
dataframe_tweets_bolsonaro.head ()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:17:32+00:00  1553520196110917633
# 1 2022-07-30 23:17:32+00:00  1553520195670622208
# 2 2022-07-30 23:17:31+00:00  1553520194328330242
# 3 2022-07-30 23:17:31+00:00  1553520193506271232
# 4 2022-07-30 23:17:31+00:00  1553520192369688578
#
#                                                Tweet  Candidato
# 0                     @jairbolsonaro Famoso gadogram  Bolsonaro
# 1  @Pauloeuaqui1 @jairbolsonaro Quem tem medo é o...  Bolsonaro
# 2  Fugir para os EUA,com certeza não vai garantir...  Bolsonaro
# 3  @Antnio3070 @MarcioM61326104 @adinaelsilva @Al...  Bolsonaro
# 4  O Manifesto do Direito via USP, com 500 mil as...  Bolsonaro

# %% [markdown]
# ### Ciro Gomes

# %%
lista_de_tweets_ciro = []

# %%
for i, tweet in enumerate (sntwitter.TwitterSearchScraper(['ciro gomes']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_ciro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro = pd.DataFrame(lista_de_tweets_ciro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_ciro.head ()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:17:46+00:00  1553520253463937026
# 1 2022-07-30 23:17:31+00:00  1553520192399065088
# 2 2022-07-30 23:17:11+00:00  1553520106633891840
# 3 2022-07-30 23:17:04+00:00  1553520077408030725
# 4 2022-07-30 23:17:04+00:00  1553520077009522689
#
#                                                Tweet
# 0  Já saiu a toalha do Ciro Gomes hahaha https://...
# 1                              @cirogomes MEIA DUZIA
# 2  @cirogomes Hahahhahahahahhahahahahahahhahahaha...
# 3                             @Eu53122667 @cirogomes
# 4  @parox40 @cirogomes Bah... na cara não...\nMag...

# %%
dataframe_tweets_ciro['Candidato'] = 'Ciro Gomes'

# %%
dataframe_tweets_ciro.head ()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:17:46+00:00  1553520253463937026
# 1 2022-07-30 23:17:31+00:00  1553520192399065088
# 2 2022-07-30 23:17:11+00:00  1553520106633891840
# 3 2022-07-30 23:17:04+00:00  1553520077408030725
# 4 2022-07-30 23:17:04+00:00  1553520077009522689
#
#                                                Tweet   Candidato
# 0  Já saiu a toalha do Ciro Gomes hahaha https://...  Ciro Gomes
# 1                              @cirogomes MEIA DUZIA  Ciro Gomes
# 2  @cirogomes Hahahhahahahahhahahahahahahhahahaha...  Ciro Gomes
# 3                             @Eu53122667 @cirogomes  Ciro Gomes
# 4  @parox40 @cirogomes Bah... na cara não...\nMag...  Ciro Gomes

# %%
dataframe_final = pd.concat([dataframe_tweets_lula, dataframe_tweets_bolsonaro, dataframe_tweets_ciro], axis = 0)

# %%
dataframe_final.head ()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-30 23:17:46+00:00  1553520255238119424
# 1 2022-07-30 23:17:46+00:00  1553520253535227906
# 2 2022-07-30 23:17:45+00:00  1553520252608192512
# 3 2022-07-30 23:17:45+00:00  1553520251211505664
# 4 2022-07-30 23:17:45+00:00  1553520250263687168
#
#                                                Tweet Candidato
# 0  @LulaOficial @dilmabr Alguém de vcs checa isso...      Lula
# 1  Presidente: Lula; Senador:?; Deputado Federal:...      Lula
# 2  @gleisi @LulaOficial @CamiloSantanaCE @elmanof...      Lula
# 3        @MARCOSDANI1 @LulaOficial NÃO...BEM REAL...      Lula
# 4  @WesleyAHS11s @LulaOficial #BolsonaroReeleitoE...      Lula

# %%
dataframe_final['Candidato'].unique()
# Out:
# array(['Lula', 'Bolsonaro', 'Ciro Gomes'], dtype=object)

# %%
dataframe_final.to_csv('datafreame_final_candidatos.csv', sep=',', index=False)
